# %%
from combined import viewer
view = viewer()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-78ebe0f0802f> in <module>
#       1 from combined import viewer
# ----> 2 view = viewer()
#
# ~/code/5dVisualizer/combined.py in __init__(self)
#      55         else:
#      56             self.client = client
# ---> 57         self.load()
#      58
#      59     def reload_files(self):
#
# ~/.conda/envs/5Dvisualizer/lib/python3.8/site-packages/param/parameterized.py in _depends(*args, **kw)
#     349     @wraps(func)
#     350     def _depends(*args,**kw):
# --> 351         return func(*args,**kw)
#     352
#     353     deps = list(dependencies)+list(kw.values())
#
# ~/code/5dVisualizer/combined.py in load(self)
#      64     def load(self):
#      65         self.reload_files()  # temp solution
# ---> 66         self.grapher = self.extensions[extension(self.filename)](self.filename, self.client)
#      67
# ...

# %%
view.servable()
